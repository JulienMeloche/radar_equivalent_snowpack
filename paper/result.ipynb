# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import binned_statistic
import seaborn as sns

#local radar_equivalent_function
import res_function as res

import warnings
warnings.filterwarnings('ignore')

# %%
#import data
#sapporo
xr_sap = xr.open_dataset('sap_season_2013.nc')
df_sap = xr_sap.to_dataframe().dropna()
df_sap['TSNOW_ML'] = df_sap['TSNOW_ML'].apply(lambda x: 273 if x > 273 else x)
#weisflu
xr_cdp = xr.open_dataset('wfj_season_2013.nc')
df_cdp = xr_cdp.to_dataframe().dropna()
df_cdp['TSNOW_ML'] = df_cdp['TSNOW_ML'].apply(lambda x: 273 if x > 273 else x)
#trail valley crek
xr_tvc = xr.open_dataset('tvc_season_2013.nc')
df_tvc = xr_tvc.to_dataframe().dropna()
df_tvc['TSNOW_ML'] = df_tvc['TSNOW_ML'].apply(lambda x: 273 if x > 273 else x)

#get list of date
dates_sap = df_sap.groupby(level = 'time').mean().index.get_level_values(0)
dates_cdp = df_cdp.groupby(level = 'time').mean().index.get_level_values(0)
dates_tvc = df_tvc.groupby(level = 'time').mean().index.get_level_values(0)

# %% [markdown]
# # Grouping and averaging simulations

# %%
cdp_sig_n, cdp_swe_n, cdp_param = res.get_sig_swe(df_cdp, dates_cdp, 'thick', 'n', model = 'iba_inv')
cdp_sig_1  = res.get_sig_swe(df_cdp, dates_cdp, 'thick', 'one', model = 'iba_inv')
cdp_sig_2 = res.get_sig_swe(df_cdp, dates_cdp, 'thick', 'two', model = 'iba_inv')
cdp_sig_2k = res.get_sig_swe(df_cdp, dates_cdp, 'thick', 'two_k', model = 'iba_inv')
cdp_sig_2k_ked = res.get_sig_swe(df_cdp, dates_cdp, 'thick-ke-density', 'two_k', model = 'iba_inv')
cdp_sig_3 = res.get_sig_swe(df_cdp, dates_cdp, 'thick', 'three', model = 'iba_inv')
cdp_sig_3_ked = res.get_sig_swe(df_cdp, dates_cdp, 'thick-ke-density', 'three', model = 'iba_inv')
cdp_sig_3k = res.get_sig_swe(df_cdp, dates_cdp, 'thick', 'three_k', model = 'iba_inv')
#cdp_sig_3k_ke = res.get_sig_swe(df_cdp, dates_cdp, 'thick-ke', 'three_k', model = 'iba_inv')
cdp_sig_3k_ked = res.get_sig_swe(df_cdp, dates_cdp, 'thick-ke-density', 'three_k', model = 'iba_inv')
# Out:
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# ...

# %%
sap_sig_n, sap_swe_n, sap_param = res.get_sig_swe(df_sap, dates_sap, 'thick', 'n', model = 'iba_inv')
sap_sig_1 = res.get_sig_swe(df_sap, dates_sap, 'thick', 'one', model = 'iba_inv')
sap_sig_2 = res.get_sig_swe(df_sap, dates_sap, 'thick', 'two', model = 'iba_inv')
sap_sig_2k = res.get_sig_swe(df_sap, dates_sap, 'thick', 'two_k', model = 'iba_inv')
sap_sig_2k_ked = res.get_sig_swe(df_sap, dates_sap, 'thick-ke-density', 'two_k', model = 'iba_inv')
sap_sig_3 = res.get_sig_swe(df_sap, dates_sap, 'thick', 'three', model = 'iba_inv')
sap_sig_3_ked = res.get_sig_swe(df_sap, dates_sap, 'thick-ke-density', 'three', model = 'iba_inv')
sap_sig_3k = res.get_sig_swe(df_sap, dates_sap, 'thick', 'three_k', model = 'iba_inv')
#sap_sig_3k_ke = res.get_sig_swe(df_sap, dates_sap, 'thick-ke', 'three_k', model = 'iba_inv')
sap_sig_3k_ked = res.get_sig_swe(df_sap, dates_sap, 'thick-ke-density', 'three_k', model = 'iba_inv')
# Out:
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component

# %%
tvc_sig_n, tvc_swe_n, tvc_param = res.get_sig_swe(df_tvc, dates_tvc, 'thick', 'n', model = 'iba_inv')
tvc_sig_1 = res.get_sig_swe(df_tvc, dates_tvc, 'thick', 'one', model = 'iba_inv')
tvc_sig_2 = res.get_sig_swe(df_tvc, dates_tvc, 'thick', 'two', model = 'iba_inv')
tvc_sig_2k = res.get_sig_swe(df_tvc, dates_tvc, 'thick', 'two_k', model = 'iba_inv')
tvc_sig_2k_ked = res.get_sig_swe(df_tvc, dates_tvc, 'thick-ke-density', 'two_k', model = 'iba_inv')
tvc_sig_3 = res.get_sig_swe(df_tvc, dates_tvc, 'thick', 'three', model = 'iba_inv')
tvc_sig_3_ked = res.get_sig_swe(df_tvc, dates_tvc, 'thick-ke-density', 'three', model = 'iba_inv')
tvc_sig_3k = res.get_sig_swe(df_tvc, dates_tvc, 'thick', 'three_k', model = 'iba_inv')
#tvc_sig_3k_ke = res.get_sig_swe(df_tvc, dates_tvc, 'thick-ke', 'three_k', model = 'iba_inv')
tvc_sig_3k_ked = res.get_sig_swe(df_tvc, dates_tvc, 'thick-ke-density', 'three_k', model = 'iba_inv')

# %%
rmse_cdp_1 = res.rmse(cdp_sig_1, cdp_sig_n)
rmse_cdp_2 = res.rmse(cdp_sig_2, cdp_sig_n)
rmse_cdp_2k = res.rmse(cdp_sig_2k, cdp_sig_n)
rmse_cdp_2k_ked = res.rmse(cdp_sig_2k_ked, cdp_sig_n)
rmse_cdp_3 = res.rmse(cdp_sig_3, cdp_sig_n)
rmse_cdp_3k = res.rmse(cdp_sig_3k, cdp_sig_n)
rmse_cdp_3k_ked = res.rmse(cdp_sig_3k_ked, cdp_sig_n)

print('cdp')
print(rmse_cdp_1, rmse_cdp_2, rmse_cdp_2k, rmse_cdp_2k_ked, rmse_cdp_3, rmse_cdp_3k, rmse_cdp_3k_ked)
# Out:
# cdp
# 4.235726348082617 3.4960083976744376 2.0970572606540863 0.3630574735351572 3.0662466644492237 1.6469222889829187 0.18300047130403474

# %%
rmse_sap_1 = res.rmse(sap_sig_1, sap_sig_n)
rmse_sap_2 = res.rmse(sap_sig_2, sap_sig_n)
rmse_sap_2k = res.rmse(sap_sig_2k, sap_sig_n)
rmse_sap_3 = res.rmse(sap_sig_3, sap_sig_n)
rmse_sap_3k = res.rmse(sap_sig_3k, sap_sig_n)
rmse_sap_3k_ked = res.rmse(sap_sig_3k_ked, sap_sig_n)

print('sap')
print(rmse_sap_1, rmse_sap_2, rmse_sap_2k, rmse_sap_3, rmse_sap_3k, rmse_sap_3k_ked)
# Out:
# sap
# 3.5826771676625757 2.5207708258558887 1.695896505331249 2.0003376859013082 1.1828790106329645 0.2544089093400083

# %%
rmse_tvc_1 = res.rmse(tvc_sig_1, tvc_sig_n)
rmse_tvc_2 = res.rmse(tvc_sig_2, tvc_sig_n)
rmse_tvc_2k = res.rmse(tvc_sig_2k, tvc_sig_n)
rmse_tvc_3 = res.rmse(tvc_sig_3, tvc_sig_n)
rmse_tvc_3k = res.rmse(tvc_sig_3k, tvc_sig_n)
rmse_tvc_3k_ked = res.rmse(tvc_sig_3k_ked, tvc_sig_n)

print('tvc')
print(rmse_tvc_1, rmse_tvc_2, rmse_tvc_2k, rmse_tvc_3, rmse_tvc_3k, rmse_tvc_3k_ked)
# Out:
# tvc
# 9.703283267286675 1.481822516010547 0.6850581923527616 0.3822608904160048 0.39592648383998846 0.2743084292045318

# %%
fig, ax = plt.subplots(1,3, figsize = (11,4), sharex = True, sharey = 'row')

#row 1
ax[0].plot(dates_cdp, cdp_sig_n, alpha = 0.7, label = 'n-layer', color = 'k')
ax[0].plot(dates_cdp, cdp_sig_3, alpha = 0.5, label = '3-layer', color = 'dodgerblue')
ax[0].plot(dates_cdp, cdp_sig_3k, alpha = 0.5, label = '3k-layer', color = 'darkorange')
ax[0].plot(dates_cdp, cdp_sig_3_ked, alpha = 0.5, label = '3k-ke-layer', color = 'green')
ax[0].plot(dates_cdp, cdp_sig_3k_ked, alpha = 0.5, label = '3k-keD-layer', color = 'red')
ax[0].grid()


ax[1].plot(dates_sap, sap_sig_n, alpha = 0.7, label = 'n-layer', color = 'k')
ax[1].plot(dates_sap, sap_sig_3, alpha = 0.5, label = '3-equal with $h$-average', color = 'dodgerblue')
ax[1].plot(dates_sap, sap_sig_3k, alpha = 0.5, label = '3-cluster with $h$-average', color = 'darkorange')
ax[1].plot(dates_sap, sap_sig_3_ked, alpha = 0.5, label = '3-equal with $\\tau$-average', color = 'green')
ax[1].plot(dates_sap, sap_sig_3k_ked, alpha = 0.5, label = '3-cluster with $\\tau$-average', color = 'red')
ax[1].grid()

# tvc
ax[2].plot(dates_tvc, tvc_sig_n, alpha = 0.7, label = 'n-layer', color = 'k')
ax[2].plot(dates_tvc, tvc_sig_3, alpha = 0.5, label = '3-equal', color = 'dodgerblue')
ax[2].plot(dates_tvc, tvc_sig_3k, alpha = 0.5, label = '3-Kmeans', color = 'darkorange')
ax[2].plot(dates_tvc, tvc_sig_3_ked, alpha = 0.5, label = '3-Kmeans-ke', color = 'green')
ax[2].plot(dates_tvc, tvc_sig_3k_ked, alpha = 0.5, label = '3-Kmeans-keD', color = 'red')
ax[2].grid()



#dates
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=45, ha='right')
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45, ha='right')
ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=45, ha='right')


ax[0].set_ylabel('$\sigma^0$ (dB)')
ax[0].set_ylabel('$\sigma^0$ (dB)')
#ax[2,0].set_ylabel('res.Bias SWE (mm)')
ax[0].set_title('WFJ')
ax[1].set_title('SAP')
ax[2].set_title('TVC')

ax[0].set_ylim(-25, -2)
ax[0].set_ylim(-25, -2)
ax[1].legend( fontsize = 8)
#ax[1,2].legend( bbox_to_anchor=(1, 1, 0.1, 0.1))
plt.subplots_adjust(hspace = 0.1)
plt.subplots_adjust(wspace = 0.05)
fig.savefig("/home/jum002/public_html/res_snowpack/fig3_sig_group.png", dpi = 300, bbox_inches = 'tight')
# Out:
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# ...

# %%
fig, ax = plt.subplots(2,3, figsize = (11,6), sharex = True, sharey = 'row')

#row 1
ax[0,0].plot(dates_cdp, cdp_sig_n, alpha = 0.7, label = 'n-layer', color = 'k')
ax[0,0].plot(dates_cdp, cdp_sig_1, alpha = 0.5, label = '1-layer', color = 'green')
ax[0,0].plot(dates_cdp, cdp_sig_2, alpha = 0.5, label = '2-layer', color = 'red')
ax[0,0].plot(dates_cdp, cdp_sig_3, alpha = 0.5, label = '3-layer', color = 'darkorange')
#ax[0,0].plot(dates_cdp, cdp_sig_3k, alpha = 0.5, label = '3k-layer', color = 'dodgerblue')
#ax[0,0].plot(dates_cdp, cdp_sig_3k_ke, alpha = 0.5, label = '3k-ke-layer', color = 'steelblue', linestyle= ':')
ax[0,0].plot(dates_cdp, cdp_sig_2k_ked, alpha = 0.5, label = '2k-layer', color = 'purple')
ax[0,0].plot(dates_cdp, cdp_sig_3k_ked, alpha = 0.6, label = '3k-keD-layer', color = 'dodgerblue')
ax[0,0].grid()


ax[0,1].plot(dates_sap, sap_sig_n, alpha = 0.7, label = 'n-layer', color = 'k')
ax[0,1].plot(dates_sap, sap_sig_1, alpha = 0.5, label = '1-layer with $h$', color = 'green')
ax[0,1].plot(dates_sap, sap_sig_2, alpha = 0.5, label = '2-equal with $h$', color = 'red')
ax[0,1].plot(dates_sap, sap_sig_3, alpha = 0.5, label = '3-equal with $h$', color = 'darkorange')
#ax[0,1].plot(dates_sap, sap_sig_3k, alpha = 0.5, label = '3-cluster with $h$', color = 'dodgerblue')
#ax[0,1].plot(dates_sap, sap_sig_3k_ke, alpha = 0.5, label = '3-Kmeans-ke', color = 'steelblue', linestyle= ':')
ax[0,1].plot(dates_sap, sap_sig_2k_ked, alpha = 0.5, label = '2-cluster with $\\tau$', color = 'purple')
ax[0,1].plot(dates_sap, sap_sig_3k_ked, alpha = 0.6, label = '3-cluster with $\\tau$', color = 'dodgerblue')
ax[0,1].grid()

# tvc
ax[0,2].plot(dates_tvc, tvc_sig_n, alpha = 0.7, label = 'n-layer', color = 'k')
ax[0,2].plot(dates_tvc, tvc_sig_1, alpha = 0.5, label = '1-layer', color = 'green')
ax[0,2].plot(dates_tvc, tvc_sig_2, alpha = 0.5, label = '2-equal', color = 'red')
ax[0,2].plot(dates_tvc, tvc_sig_3, alpha = 0.5, label = '3-equal', color = 'darkorange')
#ax[0,2].plot(dates_tvc, tvc_sig_3k, alpha = 0.5, label = '3-Kmeans', color = 'dodgerblue')
#ax[0,2].plot(dates_tvc, tvc_sig_3k_ke, alpha = 0.5, label = '3-Kmeans-ke', color = 'steelblue', linestyle= ':')
ax[0,2].plot(dates_tvc, tvc_sig_2k_ked, alpha = 0.5, label = '2-Kmeans', color = 'purple')
ax[0,2].plot(dates_tvc, tvc_sig_3k_ked, alpha = 0.6, label = '3-Kmeans-keD', color = 'dodgerblue')
ax[0,2].grid()


# #row 2
ax[1,0].plot(dates_cdp, cdp_sig_n, alpha = 0.7, label = 'n-layer', color = 'k')
ax[1,0].plot(dates_cdp, cdp_sig_3_ked, alpha = 0.5, label = '3-layer', color = 'darkorange')
ax[1,0].plot(dates_cdp, cdp_sig_3k, alpha = 0.5, label = '3k-layer', color = 'dodgerblue')
ax[1,0].plot(dates_cdp, cdp_sig_3k_ked, alpha = 0.6, label = '3k-keD-layer', color = 'dodgerblue')
ax[1,0].grid()

# #sap
ax[1,1].plot(dates_sap, sap_sig_n, alpha = 0.7, label = 'n-layer', color = 'k')
#ax[1,1].plot(dates_sap, sap_sig_3, alpha = 0.5, label = '3-equal with $h$', color = 'darkorange')
ax[1,1].plot(dates_sap, sap_sig_3k, alpha = 0.5, label = '3-cluster with $h$', color = 'dodgerblue')
ax[1,1].plot(dates_sap, sap_sig_3_ked, alpha = 0.5, label = '3-Kmeans-ke', color = 'steelblue', linestyle= ':')
ax[1,1].plot(dates_sap, sap_sig_3k_ked, alpha = 0.6, label = '3-cluster with $\\tau$', color = 'dodgerblue')
ax[1,1].grid()

# #tvc
ax[1,2].plot(dates_tvc, tvc_sig_n, alpha = 0.7, label = 'n-layer', color = 'k')
#ax[1,2].plot(dates_tvc, tvc_sig_3k, alpha = 0.5, label = '3-Kmeans', color = 'dodgerblue')
ax[1,2].plot(dates_tvc, tvc_sig_3_ked, alpha = 0.5, label = '3-Kmeans-ke', color = 'steelblue', linestyle= ':')
ax[1,2].plot(dates_tvc, tvc_sig_3k_ked, alpha = 0.6, label = '3-Kmeans-keD', color = 'dodgerblue')
ax[1,2].grid()


#dates
ax[1,0].set_xticklabels(ax[1,0].get_xticklabels(), rotation=45, ha='right')
ax[1,1].set_xticklabels(ax[1,1].get_xticklabels(), rotation=45, ha='right')
ax[1,2].set_xticklabels(ax[1,2].get_xticklabels(), rotation=45, ha='right')


ax[0,0].set_ylabel('$\sigma^0$ (dB)')
ax[1,0].set_ylabel('$\sigma^0$ (dB)')
#ax[2,0].set_ylabel('res.Bias SWE (mm)')
ax[0,0].set_title('WFJ')
ax[0,1].set_title('SAP')
ax[0,2].set_title('TVC')

ax[0,0].set_ylim(-25, -2)
ax[1,0].set_ylim(-25, -2)
ax[0,1].legend( fontsize = 8)
#ax[1,2].legend( bbox_to_anchor=(1, 1, 0.1, 0.1))
plt.subplots_adjust(hspace = 0.1)
plt.subplots_adjust(wspace = 0.05)

# %% [markdown]
# ## bias and snow properties

# %%
bins_d = np.linspace(150,450,6)
bins_s = np.linspace(8,45,6)
bins_t = np.linspace(258,274,6) - 273.2

# %%
#density
bin_means = binned_statistic(cdp_param['mean_rho'], cdp_param['mean_rho'], bins =bins_d )
df_rho_cdp = pd.DataFrame({'rho' : cdp_param['mean_rho'], 'Bias (K)' : res.bias(cdp_sig_3, cdp_sig_n), 'group' : bin_means[2], 'method': '3-equal'})
df_rho_cdp['Density'] = df_rho_cdp.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
bin_means = binned_statistic(cdp_param['mean_rho'], cdp_param['mean_rho'], bins =bins_d )
df_rho_cdp_3k = pd.DataFrame({'rho' : cdp_param['mean_rho'], 'Bias (K)' : res.bias(cdp_sig_3k, cdp_sig_n), 'group' : bin_means[2], 'method': '3-cluster'})
df_rho_cdp_3k['Density'] = df_rho_cdp_3k.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_rho_cdp = df_rho_cdp.append(df_rho_cdp_3k)

bin_means = binned_statistic(sap_param['mean_rho'], sap_param['mean_rho'], bins =bins_d)
df_rho_sap = pd.DataFrame({'rho' : sap_param['mean_rho'], 'Bias (K)' : res.bias(sap_sig_3, sap_sig_n), 'group' : bin_means[2], 'method': '3-equal'})
df_rho_sap['Density'] = df_rho_sap.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_rho_sap_3k = pd.DataFrame({'rho' : sap_param['mean_rho'], 'Bias (K)' : res.bias(sap_sig_3k, sap_sig_n), 'group' : bin_means[2], 'method': '3-cluster'})
df_rho_sap_3k['Density'] = df_rho_sap_3k.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_rho_sap = df_rho_sap.append(df_rho_sap_3k)

bin_means = binned_statistic(tvc_param['mean_rho'], tvc_param['mean_rho'], bins = bins_d)
df_rho_tvc = pd.DataFrame({'rho' : tvc_param['mean_rho'], 'Bias (K)' : res.bias(tvc_sig_3, tvc_sig_n), 'group' : bin_means[2], 'method': '3-equal'})
df_rho_tvc['Density'] = df_rho_tvc.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_rho_tvc_3k = pd.DataFrame({'rho' : tvc_param['mean_rho'], 'Bias (K)' : res.bias(tvc_sig_3k, tvc_sig_n), 'group' : bin_means[2], 'method': '3-cluster'})
df_rho_tvc_3k['Density'] = df_rho_tvc_3k.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_rho_tvc = df_rho_tvc.append(df_rho_tvc_3k)


#ssa
bin_means = binned_statistic(cdp_param['mean_ssa'], cdp_param['mean_ssa'], bins =bins_s)
df_ssa_cdp = pd.DataFrame({'ssa' : cdp_param['mean_ssa'], 'Bias (K)' : res.bias(cdp_sig_3, cdp_sig_n), 'group' : bin_means[2], 'method': '3-equal'})
df_ssa_cdp['SSA'] = df_ssa_cdp.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_ssa_cdp_3k = pd.DataFrame({'ssa' : cdp_param['mean_ssa'], 'Bias (K)' : res.bias(cdp_sig_3k, cdp_sig_n), 'group' : bin_means[2], 'method': '3-cluster'})
df_ssa_cdp_3k['SSA'] = df_ssa_cdp_3k.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_ssa_cdp = df_ssa_cdp.append(df_ssa_cdp_3k)

bin_means = binned_statistic(sap_param['mean_ssa'], sap_param['mean_ssa'], bins =bins_s)
df_ssa_sap = pd.DataFrame({'ssa' : sap_param['mean_ssa'], 'Bias (K)' : res.bias(sap_sig_3, sap_sig_n), 'group' : bin_means[2], 'method': '3-equal'})
df_ssa_sap['SSA'] = df_ssa_sap.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_ssa_sap_3k = pd.DataFrame({'ssa' : sap_param['mean_ssa'], 'Bias (K)' : res.bias(sap_sig_3k, sap_sig_n), 'group' : bin_means[2], 'method': '3-cluster'})
df_ssa_sap_3k['SSA'] = df_ssa_sap_3k.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_ssa_sap = df_ssa_sap.append(df_ssa_sap_3k)

bin_means = binned_statistic(tvc_param['mean_ssa'], tvc_param['mean_ssa'], bins =bins_s)
df_ssa_tvc = pd.DataFrame({'ssa' : tvc_param['mean_ssa'], 'Bias (K)' : res.bias(tvc_sig_3, tvc_sig_n), 'group' : bin_means[2], 'method': '3-equal'})
df_ssa_tvc['SSA'] = df_ssa_tvc.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_ssa_tvc_3k = pd.DataFrame({'ssa' : tvc_param['mean_ssa'], 'Bias (K)' : res.bias(tvc_sig_3k, tvc_sig_n), 'group' : bin_means[2], 'method': '3-cluster'})
df_ssa_tvc_3k['SSA'] = df_ssa_tvc_3k.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_ssa_tvc = df_ssa_tvc.append(df_ssa_tvc_3k)


#temp
bin_means = binned_statistic(np.array(cdp_param['mean_temp']) - 273.2, np.array(cdp_param['mean_temp']) - 273.2, bins =bins_t)
df_temp_cdp = pd.DataFrame({'temp' : np.array(cdp_param['mean_temp']) - 273.2, 'Bias (K)' : res.bias(cdp_sig_3, cdp_sig_n), 'group' : bin_means[2], 'method': '3-equal'})
df_temp_cdp['Temperature (K)'] = df_temp_cdp.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_temp_cdp_3k = pd.DataFrame({'temp' : np.array(cdp_param['mean_temp']) - 273.2, 'Bias (K)' : res.bias(cdp_sig_3k, cdp_sig_n), 'group' : bin_means[2], 'method': '3-cluster'})
df_temp_cdp_3k['Temperature (K)'] = df_temp_cdp_3k.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_temp_cdp = df_temp_cdp.append(df_temp_cdp_3k)


bin_means = binned_statistic(np.array(sap_param['mean_temp']) -273.2, np.array(sap_param['mean_temp']) -273.2, bins =bins_t)
df_temp_sap = pd.DataFrame({'temp' : np.array(sap_param['mean_temp']) -273.2, 'Bias (K)' : res.bias(sap_sig_3, sap_sig_n), 'group' : bin_means[2], 'method': '3-equal'})
df_temp_sap['Temperature (K)'] = df_temp_sap.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_temp_sap_3k = pd.DataFrame({'temp' : np.array(sap_param['mean_temp']) -273.2, 'Bias (K)' : res.bias(sap_sig_3k, sap_sig_n), 'group' : bin_means[2], 'method': '3-cluster'})
df_temp_sap_3k['Temperature (K)'] = df_temp_sap_3k.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_temp_sap = df_temp_sap.append(df_temp_sap_3k)

bin_means = binned_statistic(np.array(tvc_param['mean_temp'])-273.2, np.array(tvc_param['mean_temp'])-273.2, bins =bins_t)
df_temp_tvc = pd.DataFrame({'temp' : np.array(tvc_param['mean_temp'])-273.2, 'Bias (K)' : res.bias(tvc_sig_3, tvc_sig_n), 'group' : bin_means[2], 'method': '3-equal'})
df_temp_tvc['Temperature (K)'] = df_temp_tvc.apply(lambda x: int(bin_means[1][int(x.group)]), axis =1 )
df_temp_tvc_3k = pd.DataFrame({'temp' : np.array(tvc_param['mean_temp'])-273.2, 'Bias (K)' : res.bias(tvc_sig_3k, tvc_sig_n), 'group' : bin_means[2], 'method': '3-cluster'})
df_temp_tvc_3k['Temperature (K)'] = df_temp_tvc_3k.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )
df_temp_tvc = df_temp_tvc.append(df_temp_tvc_3k)

# #wet
# wet_ratio = np.array(cdp_param['wet'])/np.array(cdp_swe_n)
# bin_means = binned_statistic(wet_ratio, wet_ratio, bins =10)
# df_wet_cdp = pd.DataFrame({'wet' : wet_ratio, 'Bias (K)' : res.bias(cdp_sig_3, cdp_sig_n), 'group' : bin_means[2]})
# df_wet_cdp['LWC (%)'] = df_wet_cdp.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )

# wet_ratio = np.array(sap_param['wet'])/np.array(sap_swe_n)
# bin_means = binned_statistic(wet_ratio, wet_ratio, bins =10)
# df_wet_sap = pd.DataFrame({'wet' : wet_ratio, 'Bias (K)' : res.bias(sap_sig_3, sap_sig_n), 'group' : bin_means[2]})
# df_wet_sap['LWC (%)'] = df_wet_sap.apply(lambda x: int(bin_means[1][int(x.group)]) , axis =1 )

# %%
fig, ax = plt.subplots(3,3, figsize = (9,6), sharey = True)

sns.boxplot(x= df_rho_cdp['Density'], y= df_rho_cdp['Bias (K)'], hue = df_rho_cdp['method'], saturation = 0.5, fliersize = 1, whis = 2 , 
            ax = ax[0,0], order=[int(d) for d in bins_d], linewidth =0.7)
ax[0,0].get_legend().remove()
sns.boxplot(x= df_rho_sap['Density'], y= df_rho_sap['Bias (K)'], hue = df_rho_sap['method'], saturation = 0.5, fliersize = 1, whis = 2 ,
             ax = ax[0,1], order=[int(d) for d in bins_d], linewidth =0.7)
ax[0,1].get_legend().remove()
sns.boxplot(x= df_rho_tvc['Density'], y= df_rho_tvc['Bias (K)'], hue = df_rho_tvc['method'], saturation = 0.5, fliersize = 1, whis = 2 , 
            ax = ax[0,2], order=[int(d) for d in bins_d], linewidth =0.7)
#ax[0,2].get_legend().remove()


sns.boxplot(x= df_ssa_cdp['SSA'], y= df_ssa_cdp['Bias (K)'], hue = df_ssa_cdp['method'], saturation = 0.5, fliersize = 1, whis = 2 , 
            ax = ax[1,0], order=[int(s) for s in bins_s], linewidth =0.7)
ax[1,0].get_legend().remove()
sns.boxplot(x= df_ssa_sap['SSA'], y= df_ssa_sap['Bias (K)'], hue = df_ssa_sap['method'], saturation = 0.5, fliersize = 1, whis = 2 , 
            ax = ax[1,1], order=[int(s) for s in bins_s], linewidth =0.7)
ax[1,1].get_legend().remove()
sns.boxplot(x= df_ssa_tvc['SSA'], y= df_ssa_tvc['Bias (K)'], hue = df_ssa_tvc['method'], saturation = 0.5, fliersize = 1, whis = 2 , 
            ax = ax[1,2], order=[int(s) for s in bins_s], linewidth =0.7)
ax[1,2].get_legend().remove()



sns.boxplot(x= df_temp_cdp['Temperature (K)'], y= df_temp_cdp['Bias (K)'], hue = df_temp_cdp['method'], saturation = 0.5, fliersize = 1, whis = 2 ,
             ax = ax[2,0], order = [int(t) for t in bins_t], linewidth =0.7)
ax[2,0].get_legend().remove()
sns.boxplot(x= df_temp_sap['Temperature (K)'], y= df_temp_sap['Bias (K)'], hue = df_temp_sap['method'], saturation = 0.5, fliersize = 1, whis = 2 ,
             ax = ax[2,1], order = [int(t) for t in bins_t], linewidth =0.7)
ax[2,1].get_legend().remove()
sns.boxplot(x= df_temp_tvc['Temperature (K)'], y= df_temp_tvc['Bias (K)'], hue = df_temp_tvc['method'], saturation = 1, fliersize = 1, whis = 2 ,
            ax = ax[2,2], order = [int(t) for t in bins_t], linewidth =0.7)
ax[2,2].get_legend().remove()


#dates
ax[0,0].set_xticklabels(ax[0,0].get_xticklabels(), size = 8, rotation=45)
ax[0,1].set_xticklabels(ax[0,1].get_xticklabels(), size = 8, rotation=45)
ax[0,2].set_xticklabels(ax[0,2].get_xticklabels(), size = 8, rotation=45)


ax[1,0].set_xticklabels(ax[1,0].get_xticklabels(), size = 8)
ax[1,1].set_xticklabels(ax[1,1].get_xticklabels(), size = 8)
ax[1,2].set_xticklabels(ax[1,2].get_xticklabels(), size = 8)

ax[2,0].set_xticklabels(ax[2,0].get_xticklabels(), size = 8, rotation=45)
ax[2,1].set_xticklabels(ax[2,1].get_xticklabels(), size = 8, rotation=45)
ax[2,2].set_xticklabels(ax[2,2].get_xticklabels(), size = 8, rotation=45)

# sns.boxplot(x= df_wet_cdp['LWC (%)'], y= df_wet_cdp['Bias (K)'], saturation = 0.5, fliersize = 2, whis = 2 , ax = ax[2,0], palette = 'flare')
# sns.boxplot(x= df_wet_sap['LWC (%)'], y= df_wet_sap['Bias (K)'], saturation = 0.5, fliersize = 2, whis = 2 , ax = ax[2,1], palette = 'flare')
ax[0,0].set_title('WFJ')
ax[0,1].set_title('SAP')
ax[0,2].set_title('TVC')

ax[0,0].set_xlabel('Density ($kg \ m^{-3}$)', size = 9)
ax[0,1].set_xlabel('Density ($kg \ m^{-3}$)', size = 9)
ax[0,2].set_xlabel('Density ($kg \ m^{-3}$)', size = 9)

ax[1,0].set_xlabel('SSA ($m^2 \ kg^{-1}$)', size = 9)
ax[1,1].set_xlabel('SSA ($m^2 \ kg^{-1}$)', size = 9)
ax[1,2].set_xlabel('SSA ($m^2 \ kg^{-1}$)', size = 9)

ax[2,0].set_xlabel('Temperature (C$\degree$)', size = 9)
ax[2,1].set_xlabel('Temperature (C$\degree$)', size = 9)
ax[2,2].set_xlabel('Temperature (C$\degree$)', size = 9)

# ax[0,0].set_yticklabels(ax[0,0].get_yticklabels(), size = 9)
# ax[1,0].set_yticklabels(ax[1,0].get_yticklabels(), size = 9)
# ax[2,0].set_yticklabels(ax[2,0].get_yticklabels(), size = 9)

ax[0,0].set_ylabel('Difference (dB)', size = 10)
ax[1,0].set_ylabel('Difference (dB)', size = 10)
ax[2,0].set_ylabel('Difference (dB)', size = 10)

ax[0,1].set_ylabel('')
ax[1,1].set_ylabel('')
ax[2,1].set_ylabel('')

ax[0,2].set_ylabel('')
ax[1,2].set_ylabel('')
ax[2,2].set_ylabel('')

ax[0,0].grid()
ax[0,1].grid()
ax[0,2].grid()

ax[1,0].grid()
ax[1,1].grid()
ax[1,2].grid()

ax[2,0].grid()
ax[2,1].grid()
ax[2,2].grid()

ax[0,2].legend(loc =4, fontsize=10)

# import matplotlib.patches as mpatches
# red_patch = mpatches.Patch(color='darkorange', label='3-equal', alpha = 0.5)
# purple_patch = mpatches.Patch(color='dodgerblue', label='3-Kmeans', alpha = 0.5)
# ax[0,2].legend(handles=[red_patch, purple_patch], loc =4)

plt.subplots_adjust(hspace = 0.5)
plt.subplots_adjust(wspace = 0.05)
fig.savefig("/home/jum002/public_html/res_snowpack/fig4_bias_snow.png", dpi = 300)

# %%
res.get_sig_swe(df_cdp, dates_cdp, 'thick', 'three', model = 'iba_inv', freq = 17e9)
# Out:
# array([-15.73682317, -15.80978332, -15.91784949, -15.84866127,
#        -15.90048902, -15.97101373, -17.67096824, -17.64266366,
#        -17.58928609, -17.63313761, -17.71328657, -17.78938997,
#        -17.56762669, -17.36977411, -15.80683081, -15.74862663,
#        -15.71912177, -16.0921367 , -20.58804958, -20.95566369,
#        -20.5432031 , -20.1912034 , -19.84740389, -19.50259209,
#        -19.18549706, -18.88090589, -17.42979665, -17.2011339 ,
#        -17.02671721, -16.99922681, -18.15378733, -18.19032802,
#        -18.18942542, -18.15953528, -18.08059838, -18.07034538,
#        -18.22611181, -18.46836821, -18.34407623, -18.21600511,
#        -17.76912604, -17.64770362, -17.50718739, -17.36299397,
#        -17.24538545, -17.12109607, -17.02660803, -16.95208352,
#        -16.89744787, -16.84606681, -16.80205796, -16.99323314,
#        -17.35569237, -17.3681911 , -17.4416767 , -17.19686952,
#        -17.1349515 , -17.08474938, -17.01940787, -16.91961256,
# ...

# %% [markdown]
# #### frequency analysis

# %%
f_array = np.linspace(10,40, 10)
cdp_sig_n_f = [res.get_sig_swe(df_cdp, dates_cdp, 'thick', 'n', model = 'iba_inv', freq = f*1e9)[0] for f in f_array]
cdp_sig_3_f =  [res.get_sig_swe(df_cdp, dates_cdp, 'thick', 'three', model = 'iba_inv', freq = f*1e9) for f in f_array]
cdp_sig_3k_f = [res.get_sig_swe(df_cdp, dates_cdp, 'thick-ke-density', 'three_k', model = 'iba_inv', freq = f*1e9) for f in f_array]

# rmse_cdp_3 = [res.rmse(sig_n, sig_3) for sig_n, sig_3 in zip(cdp_sig_n, cdp_sig_3)]
# rmse_cdp_3_3k = [res.rmse(sig_3, sig_3k) for sig_3, sig_3k in zip(cdp_sig_3, cdp_sig_3k)]
# rmse_cdp_3k = [res.rmse(sig_n, sig_3k) for sig_n, sig_3k in zip(cdp_sig_n, cdp_sig_3k)]

mean_cdp_sig_n = [np.mean(sig_n) for sig_n in cdp_sig_n_f]
mean_cdp_sig_3 = [np.mean(sig_3) for sig_3 in cdp_sig_3_f]
mean_cdp_sig_3k = [np.mean(sig_3k) for sig_3k in cdp_sig_3k_f]
# Out:
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# ...

# %%
tvc_sig_n_f = [res.get_sig_swe(df_tvc, dates_tvc, 'thick', 'n', model = 'iba_inv', freq = f*1e9)[0] for f in f_array]
tvc_sig_3_f =  [res.get_sig_swe(df_tvc, dates_tvc, 'thick', 'three', model = 'iba_inv', freq = f*1e9) for f in f_array]
tvc_sig_3k_f = [res.get_sig_swe(df_tvc, dates_tvc, 'thick-ke-density', 'three_k', model = 'iba_inv', freq = f*1e9) for f in f_array]

# rmse_tvc_3 = [res.rmse(sig_n, sig_3) for sig_n, sig_3 in zip(tvc_sig_n, tvc_sig_3)]
# rmse_tvc_3_3k = [res.rmse(sig_3, sig_3k) for sig_3, sig_3k in zip(tvc_sig_3, tvc_sig_3k)]
# rmse_tvc_3k = [res.rmse(sig_n, sig_3k) for sig_n, sig_3k in zip(tvc_sig_n, tvc_sig_3k)]

mean_tvc_sig_n = [np.mean(sig_n) for sig_n in tvc_sig_n_f]
mean_tvc_sig_3 = [np.mean(sig_3) for sig_3 in tvc_sig_3_f]
mean_tvc_sig_3k = [np.mean(sig_3k) for sig_3k in tvc_sig_3k_f]

# %%
sap_sig_n_f = [res.get_sig_swe(df_sap, dates_sap, 'thick', 'n', model = 'iba_inv', freq = f*1e9)[0] for f in f_array]
sap_sig_3_f =  [res.get_sig_swe(df_sap, dates_sap, 'thick', 'three', model = 'iba_inv', freq = f*1e9) for f in f_array]
sap_sig_3k_f = [res.get_sig_swe(df_sap, dates_sap, 'thick-ke-density', 'three_k', model = 'iba_inv', freq = f*1e9) for f in f_array]

# rmse_sap_3 = [res.rmse(sig_n, sig_3) for sig_n, sig_3 in zip(sap_sig_n, sap_sig_3)]
# rmse_sap_3_3k = [res.rmse(sig_3, sig_3k) for sig_3, sig_3k in zip(sap_sig_3, sap_sig_3k)]
# rmse_sap_3k = [res.rmse(sig_n, sig_3k) for sig_n, sig_3k in zip(sap_sig_n, sap_sig_3k)]

mean_sap_sig_n = [np.mean(sig_n) for sig_n in sap_sig_n_f]
mean_sap_sig_3 = [np.mean(sig_3) for sig_3 in sap_sig_3_f]
mean_sap_sig_3k = [np.mean(sig_3k) for sig_3k in sap_sig_3k_f]
# Out:
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component
# active model is not yet fully implemented, need modification for the third component

# %%
# ax[0,0].plot(f_array, mean_tvc_sig_n, label = 'n', color = 'black')
# ax[0,0].plot(f_array, mean_tvc_sig_3, label = '3')
# ax[0,0].plot(f_array, mean_tvc_sig_3k, label = '3k')
# ax[0,0].legend()

# ax[1,0].plot(f_array, rmse_tvc_3/np.array(mean_tvc_sig_n), label = 'n - 3')
# ax[1,0].plot(f_array, rmse_tvc_3k/np.array(mean_tvc_sig_3), label = 'n - 3k')
# ax[1,0].plot(f_array, rmse_tvc_3_3k/np.array(mean_tvc_sig_3k), label = '3 - 3k')
# ax[1,0].legend()

# %%
fig, ax = plt.subplots(1,3,figsize = (9,3) , sharey = 'row', sharex = True)
ax[0].plot(f_array, mean_cdp_sig_n, label = 'n', color = 'black')
ax[0].plot(f_array, mean_cdp_sig_3, label = '3-equal', color = 'darkorange')
ax[0].plot(f_array, mean_cdp_sig_3k, label = '3-Kmeans', color = 'dodgerblue')

ax[1].plot(f_array, mean_sap_sig_n, label = 'n', color = 'black')
ax[1].plot(f_array, mean_sap_sig_3, label = '3', color = 'darkorange')
ax[1].plot(f_array, mean_sap_sig_3k, label = '3k', color = 'dodgerblue')

ax[2].plot(f_array, mean_tvc_sig_n, label = 'n', color = 'black')
ax[2].plot(f_array, mean_tvc_sig_3, label = '3-equal with $h$-average', color = 'darkorange')
ax[2].plot(f_array, mean_tvc_sig_3k, label = '3-cluster with $\\tau$-average', color = 'dodgerblue')
ax[2].legend(prop={'size': 9})

ax[0].set_xlim(10,40)

ax[0].set_xlabel('Frequency (GHz)')
ax[1].set_xlabel('Frequency (GHz)')
ax[2].set_xlabel('Frequency (GHz)')
ax[0].set_ylabel('$\sigma^0$ (dB) ')
#ax[0].set_ylabel('RMSE (dB) ')

ax[0].set_title('WFJ')
ax[1].set_title('SAP')
ax[2].set_title('TVC')

ax[0].grid()
ax[1].grid()
ax[2].grid()


plt.subplots_adjust(wspace = 0.15)
fig.savefig("/home/jum002/public_html/res_snowpack/fig5_frequency.png", dpi = 300, bbox_inches = 'tight')
